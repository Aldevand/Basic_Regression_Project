# %%
# import library
import pandas as pd
import numpy as np
import os
print("pustaka berhasil dimuat")
# Out:
# pustaka berhasil dimuat

# %%
# buat jalur
folder = os.path.join("..", "data")
file = "Data_Training.csv"
path = os.path.join(folder, file)
print("jelaur universal berhasil dibuat", {path})
# Out:
# jelaur universal berhasil dibuat {'..\\data\\Data_Training.csv'}

# %%
# baca daca dari jalur yang sudah dibuat
df = pd.read_csv(path)
df.head(5)
# Out:
#    Periode     Bulan  Tidak/belum pernah sekolah  Tidak/belum tamat SD  \
# 0     2006  Februari                      234465                614960
# 1     2006   Agustus                      170666                611254
# 2     2007  Februari                      145750                520316
# 3     2007   Agustus                       94301                438519
# 4     2008  Februari                       79764                448431
#
#         SD     SLTP  SLTA Umum/SMU  SLTA Kejuruan/SMK  Akademi/Diploma  \
# 0  2675459  2860007        2842876            1204140           297185
# 1  2589699  2730045        2851518            1305190           278074
# 2  2753548  2643062        2630360            1114675           330316
# 3  2179792  2264198        2532204            1538349           397191
# 4  2216748  2166619        2204377            1165582           519867
#
#    Universitas     Total
# 0       375601  11104693
# 1       395554  10932000
# 2       409890  10547917
# ...

# %%
# cek informasi dataset
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Periode                     35 non-null     int64
#  1   Bulan                       35 non-null     object
#  2   Tidak/belum pernah sekolah  35 non-null     int64
#  3   Tidak/belum tamat SD        35 non-null     int64
#  4   SD                          35 non-null     int64
#  5   SLTP                        35 non-null     int64
#  6   SLTA Umum/SMU               35 non-null     int64
#  7   SLTA Kejuruan/SMK           35 non-null     int64
#  8   Akademi/Diploma             35 non-null     int64
#  9   Universitas                 35 non-null     int64
#  10  Total                       35 non-null     int64
# dtypes: int64(10), object(1)
# memory usage: 3.1+ KB
# None

# %%
df
# Out:
#     Periode     Bulan  Tidak/belum pernah sekolah  Tidak/belum tamat SD  \
# 0      2006  Februari                      234465                614960
# 1      2006   Agustus                      170666                611254
# 2      2007  Februari                      145750                520316
# 3      2007   Agustus                       94301                438519
# 4      2008  Februari                       79764                448431
# 5      2008   Agustus                      103206                443832
# 6      2009  Februari                       60347                415955
# 7      2009   Agustus                       90471                547430
# 8      2010  Februari                       59066                547164
# 9      2010   Agustus                      157586                600221
# 10     2011  Februari                       93956                559661
# 11     2011   Agustus                      205388                737610
# ...

# %%
# buat kamus konversi manual bulan indo -> inggris
bulan_map = {
    'Januari': 'January',
    'Februari': 'February',
    'Maret': 'March',
    'April': 'April',
    'Mei': 'May',
    'Juni': 'June',
    'Juli': 'July',
    'Agustus': 'August',
    'September': 'September',
    'Oktober': 'October',
    'November': 'November',
    'Desember': 'December'
}
df["bulan"] = df["Bulan"].map(bulan_map)

df["gabungan"] = df["Periode"].astype(str) + ' ' + df["bulan"]

df["Waktu"] = pd.to_datetime(df["gabungan"], format="%Y %B", errors="coerce")

# %%
# hapus kolom" lama
#df = df.drop(columns=["Periode", "Bulan","bulan", "gabungan"])
df.head(5)
# Out:
#    Tidak/belum pernah sekolah  Tidak/belum tamat SD       SD     SLTP  \
# 0                      234465                614960  2675459  2860007
# 1                      170666                611254  2589699  2730045
# 2                      145750                520316  2753548  2643062
# 3                       94301                438519  2179792  2264198
# 4                       79764                448431  2216748  2166619
#
#    SLTA Umum/SMU  SLTA Kejuruan/SMK  Akademi/Diploma  Universitas     Total  \
# 0        2842876            1204140           297185       375601  11104693
# 1        2851518            1305190           278074       395554  10932000
# 2        2630360            1114675           330316       409890  10547917
# 3        2532204            1538349           397191       566588  10011142
# 4        2204377            1165582           519867       626202   9427590
#
#        Waktu
# 0 2006-02-01
# 1 2006-08-01
# 2 2007-02-01
# 3 2007-08-01
# 4 2008-02-01

# %%
# cek hasil konversi
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Tidak/belum pernah sekolah  35 non-null     int64
#  1   Tidak/belum tamat SD        35 non-null     int64
#  2   SD                          35 non-null     int64
#  3   SLTP                        35 non-null     int64
#  4   SLTA Umum/SMU               35 non-null     int64
#  5   SLTA Kejuruan/SMK           35 non-null     int64
#  6   Akademi/Diploma             35 non-null     int64
#  7   Universitas                 35 non-null     int64
#  8   Total                       35 non-null     int64
#  9   Waktu                       35 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(9)
# memory usage: 2.9 KB

# %%
# simpan hasilnya konversi 
df.to_csv("Data_Preprocessing1.csv", index=False)

# %%
df = pd.read_csv("Data_Preprocessing1.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Tidak/belum pernah sekolah  35 non-null     int64
#  1   Tidak/belum tamat SD        35 non-null     int64
#  2   SD                          35 non-null     int64
#  3   SLTP                        35 non-null     int64
#  4   SLTA Umum/SMU               35 non-null     int64
#  5   SLTA Kejuruan/SMK           35 non-null     int64
#  6   Akademi/Diploma             35 non-null     int64
#  7   Universitas                 35 non-null     int64
#  8   Total                       35 non-null     int64
#  9   Waktu                       35 non-null     object
# dtypes: int64(9), object(1)
# memory usage: 2.9+ KB
